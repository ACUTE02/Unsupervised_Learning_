# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
X=df.drop('species',axis=1)
y=df['species']

# %%
model_knn=KNeighborsClassifier()
model_svm=SVC()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
svm_pipeline=Pipeline([('scalar',StandardScaler()),('Classifier',model_svm)])
knn_pipeline = Pipeline([('scaler', StandardScaler()),('knn_classifer', model_knn)])

score_svm=cross_val_score(svm_pipeline, X, y, cv=5)
score_knn=cross_val_score(knn_pipeline, X, y, cv=5)
print(score_svm.mean(),"this is SVM ")
print(score_knn.mean(),"This is KNN")
# Out:
# 0.9666666666666666 this is SVM
# 0.96 This is KNN

# %%
#"Grid_search_cv"

# %%
from sklearn.model_selection import GridSearchCV
parameter={'Classifier__C':[1,10,20,30],'Classifier__kernel':['linear','rbf'],'Classifier__gamma':['scale','auto']}
grid = GridSearchCV(
    svm_pipeline,
    parameter,
    cv=5,
    return_train_score=True
)
grid.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scalar', StandardScaler()),
#                                        ('Classifier', SVC())]),
#              param_grid={'Classifier__C': [1, 10, 20, 30],
#                          'Classifier__gamma': ['scale', 'auto'],
#                          'Classifier__kernel': ['linear', 'rbf']},
#              return_train_score=True)

# %%
print("Best Parameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)
# Out:
# Best Parameters: {'Classifier__C': 10, 'Classifier__gamma': 'scale', 'Classifier__kernel': 'rbf'}
# Best Accuracy: 0.9733333333333334

# %%
results = pd.DataFrame(grid.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007443      0.001395         0.003543        0.000330
# 1        0.006224      0.000219         0.003219        0.000168
# 2        0.006682      0.000396         0.003498        0.000241
# 3        0.007170      0.001279         0.003474        0.000061
# 4        0.006417      0.000318         0.003204        0.000111
# 5        0.006413      0.000479         0.003226        0.000183
# 6        0.006377      0.000742         0.003153        0.000295
# 7        0.006209      0.000280         0.003176        0.000137
# 8        0.006177      0.000376         0.003067        0.000106
# 9        0.006453      0.000287         0.003294        0.000167
# 10       0.006037      0.000098         0.003078        0.000028
# 11       0.006307      0.000221         0.003187        0.000096
# 12       0.006985      0.000338         0.003592        0.000446
# 13       0.007977      0.001436         0.004427        0.000929
# 14       0.006505      0.000421         0.004359        0.000740
# 15       0.007409      0.000889         0.003710        0.000304
#
#     param_Classifier__C param_Classifier__gamma param_Classifier__kernel  \
# 0                     1                   scale                   linear
# 1                     1                   scale                      rbf
# 2                     1                    auto                   linear
# 3                     1                    auto                      rbf
# 4                    10                   scale                   linear
# 5                    10                   scale                      rbf
# 6                    10                    auto                   linear
# 7                    10                    auto                      rbf
# 8                    20                   scale                   linear
# 9                    20                   scale                      rbf
# 10                   20                    auto                   linear
# 11                   20                    auto                      rbf
# 12                   30                   scale                   linear
# 13                   30                   scale                      rbf
# 14                   30                    auto                   linear
# 15                   30                    auto                      rbf
#
#                                                params  split0_test_score  \
# 0   {'Classifier__C': 1, 'Classifier__gamma': 'sca...           0.966667
# 1   {'Classifier__C': 1, 'Classifier__gamma': 'sca...           0.966667
# 2   {'Classifier__C': 1, 'Classifier__gamma': 'aut...           0.966667
# 3   {'Classifier__C': 1, 'Classifier__gamma': 'aut...           0.966667
# 4   {'Classifier__C': 10, 'Classifier__gamma': 'sc...           1.000000
# 5   {'Classifier__C': 10, 'Classifier__gamma': 'sc...           1.000000
# 6   {'Classifier__C': 10, 'Classifier__gamma': 'au...           1.000000
# 7   {'Classifier__C': 10, 'Classifier__gamma': 'au...           1.000000
# 8   {'Classifier__C': 20, 'Classifier__gamma': 'sc...           1.000000
# 9   {'Classifier__C': 20, 'Classifier__gamma': 'sc...           1.000000
# 10  {'Classifier__C': 20, 'Classifier__gamma': 'au...           1.000000
# 11  {'Classifier__C': 20, 'Classifier__gamma': 'au...           1.000000
# 12  {'Classifier__C': 30, 'Classifier__gamma': 'sc...           1.000000
# 13  {'Classifier__C': 30, 'Classifier__gamma': 'sc...           1.000000
# 14  {'Classifier__C': 30, 'Classifier__gamma': 'au...           1.000000
# 15  {'Classifier__C': 30, 'Classifier__gamma': 'au...           1.000000
#
#     split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0            1.000000  ...         0.966667        0.029814                3
# 1            0.966667  ...         0.966667        0.021082                9
# 2            1.000000  ...         0.966667        0.029814                3
# 3            0.966667  ...         0.966667        0.021082                9
# 4            0.966667  ...         0.960000        0.038873               13
# 5            0.966667  ...         0.973333        0.024944                1
# 6            0.966667  ...         0.960000        0.038873               13
# 7            0.966667  ...         0.973333        0.024944                1
# 8            1.000000  ...         0.966667        0.042164                9
# 9            0.966667  ...         0.966667        0.029814                3
# 10           1.000000  ...         0.966667        0.042164                9
# 11           0.966667  ...         0.966667        0.029814                3
# 12           1.000000  ...         0.960000        0.048990               13
# 13           0.966667  ...         0.966667        0.029814                3
# 14           1.000000  ...         0.960000        0.048990               13
# 15           0.966667  ...         0.966667        0.029814                3
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.966667            0.966667            0.983333
# 1             0.966667            0.975000            0.983333
# 2             0.966667            0.966667            0.983333
# 3             0.966667            0.975000            0.983333
# 4             0.975000            0.966667            0.991667
# 5             0.983333            0.983333            0.991667
# 6             0.975000            0.966667            0.991667
# 7             0.983333            0.983333            0.991667
# 8             0.975000            0.966667            0.991667
# 9             0.983333            0.983333            0.991667
# 10            0.975000            0.966667            0.991667
# 11            0.983333            0.983333            0.991667
# 12            0.975000            0.975000            0.991667
# 13            0.983333            0.983333            0.991667
# 14            0.975000            0.975000            0.991667
# 15            0.983333            0.983333            0.991667
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.975000            0.966667          0.971667         0.006667
# 1             0.983333            0.966667          0.975000         0.007454
# 2             0.975000            0.966667          0.971667         0.006667
# 3             0.983333            0.966667          0.975000         0.007454
# 4             0.991667            0.966667          0.978333         0.011304
# 5             0.983333            0.983333          0.985000         0.003333
# 6             0.991667            0.966667          0.978333         0.011304
# 7             0.983333            0.983333          0.985000         0.003333
# 8             1.000000            0.975000          0.981667         0.012247
# 9             0.991667            0.983333          0.986667         0.004082
# 10            1.000000            0.975000          0.981667         0.012247
# 11            0.991667            0.983333          0.986667         0.004082
# 12            1.000000            0.975000          0.983333         0.010541
# 13            1.000000            0.983333          0.988333         0.006667
# 14            1.000000            0.975000          0.983333         0.010541
# 15            1.000000            0.983333          0.988333         0.006667
#
# [16 rows x 23 columns]

# %%
results[['param_Classifier__C','param_Classifier__gamma','param_Classifier__kernel','mean_test_score','mean_train_score']]
# Out:
#     param_Classifier__C param_Classifier__gamma param_Classifier__kernel  \
# 0                     1                   scale                   linear
# 1                     1                   scale                      rbf
# 2                     1                    auto                   linear
# 3                     1                    auto                      rbf
# 4                    10                   scale                   linear
# 5                    10                   scale                      rbf
# 6                    10                    auto                   linear
# 7                    10                    auto                      rbf
# 8                    20                   scale                   linear
# 9                    20                   scale                      rbf
# 10                   20                    auto                   linear
# 11                   20                    auto                      rbf
# 12                   30                   scale                   linear
# 13                   30                   scale                      rbf
# 14                   30                    auto                   linear
# 15                   30                    auto                      rbf
#
#     mean_test_score  mean_train_score
# 0          0.966667          0.971667
# 1          0.966667          0.975000
# 2          0.966667          0.971667
# 3          0.966667          0.975000
# 4          0.960000          0.978333
# 5          0.973333          0.985000
# 6          0.960000          0.978333
# 7          0.973333          0.985000
# 8          0.966667          0.981667
# 9          0.966667          0.986667
# 10         0.966667          0.981667
# 11         0.966667          0.986667
# 12         0.960000          0.983333
# 13         0.966667          0.988333
# 14         0.960000          0.983333
# 15         0.966667          0.988333

# %%
#grid search in kNN
knn_parameter = {
    'knn_classifer__n_neighbors': [3,5,7,9,11],
    'knn_classifer__weights': ['uniform','distance'],
    'knn_classifer__metric': ['euclidean','manhattan']
}

classifier = GridSearchCV(
    knn_pipeline,
    knn_parameter,
    cv=5,
    scoring='accuracy',
    return_train_score=True
)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn_classifer',
#                                         KNeighborsClassifier())]),
#              param_grid={'knn_classifer__metric': ['euclidean', 'manhattan'],
#                          'knn_classifer__n_neighbors': [3, 5, 7, 9, 11],
#                          'knn_classifer__weights': ['uniform', 'distance']},
#              return_train_score=True, scoring='accuracy')

# %%
print("Best Parameters:", classifier.best_params_)
print("Best Accuracy:", classifier.best_score_)
results_knn=pd.DataFrame(classifier.cv_results_)
# Out:
# Best Parameters: {'knn_classifer__metric': 'euclidean', 'knn_classifer__n_neighbors': 7, 'knn_classifer__weights': 'distance'}
# Best Accuracy: 0.9666666666666666

# %%
results_knn[['param_knn_classifer__metric',	'param_knn_classifer__n_neighbors',	'param_knn_classifer__weights','mean_train_score','mean_test_score'	]]
# Out:
#    param_knn_classifer__metric  param_knn_classifer__n_neighbors  \
# 0                    euclidean                                 3
# 1                    euclidean                                 3
# 2                    euclidean                                 5
# 3                    euclidean                                 5
# 4                    euclidean                                 7
# 5                    euclidean                                 7
# 6                    euclidean                                 9
# 7                    euclidean                                 9
# 8                    euclidean                                11
# 9                    euclidean                                11
# 10                   manhattan                                 3
# 11                   manhattan                                 3
# 12                   manhattan                                 5
# 13                   manhattan                                 5
# 14                   manhattan                                 7
# 15                   manhattan                                 7
# 16                   manhattan                                 9
# 17                   manhattan                                 9
# 18                   manhattan                                11
# 19                   manhattan                                11
#
#    param_knn_classifer__weights  mean_train_score  mean_test_score
# 0                       uniform          0.960000         0.953333
# 1                      distance          1.000000         0.953333
# 2                       uniform          0.960000         0.960000
# 3                      distance          1.000000         0.960000
# 4                       uniform          0.965000         0.960000
# 5                      distance          1.000000         0.966667
# 6                       uniform          0.963333         0.960000
# 7                      distance          1.000000         0.966667
# 8                       uniform          0.958333         0.946667
# 9                      distance          1.000000         0.960000
# 10                      uniform          0.960000         0.953333
# 11                     distance          1.000000         0.953333
# 12                      uniform          0.961667         0.946667
# 13                     distance          1.000000         0.946667
# 14                      uniform          0.958333         0.960000
# 15                     distance          1.000000         0.953333
# 16                      uniform          0.955000         0.946667
# 17                     distance          1.000000         0.946667
# 18                      uniform          0.961667         0.946667
# 19                     distance          1.000000         0.953333

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV(
    svm_pipeline,
    parameter,
    cv=5,
    n_iter = 4
)

# %%
classifier_r.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scalar', StandardScaler()),
#                                              ('Classifier', SVC())]),
#                    n_iter=4,
#                    param_distributions={'Classifier__C': [1, 10, 20, 30],
#                                         'Classifier__gamma': ['scale', 'auto'],
#                                         'Classifier__kernel': ['linear',
#                                                                'rbf']})

# %%
results_r=pd.DataFrame(classifier_r.cv_results_)
results_r
#print(len(classifier_r.cv_results_['params']))
#results_r[['params', 'mean_test_score']]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.005794      0.001105         0.002929        0.000629
# 1       0.004063      0.000152         0.002087        0.000029
# 2       0.004104      0.000148         0.002209        0.000068
# 3       0.004458      0.000144         0.002172        0.000057
#
#   param_Classifier__kernel param_Classifier__gamma  param_Classifier__C  \
# 0                      rbf                   scale                    1
# 1                   linear                    auto                   20
# 2                   linear                   scale                   20
# 3                      rbf                   scale                   20
#
#                                               params  split0_test_score  \
# 0  {'Classifier__kernel': 'rbf', 'Classifier__gam...           0.966667
# 1  {'Classifier__kernel': 'linear', 'Classifier__...           1.000000
# 2  {'Classifier__kernel': 'linear', 'Classifier__...           1.000000
# 3  {'Classifier__kernel': 'rbf', 'Classifier__gam...           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.966667           0.966667           0.933333                1.0
# 1           1.000000           0.900000           0.933333                1.0
# 2           1.000000           0.900000           0.933333                1.0
# 3           0.966667           0.933333           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.021082                2
# 1         0.966667        0.042164                2
# 2         0.966667        0.042164                2
# 3         0.966667        0.029814                1

# %%
#"for the KNN"

# %%
classifier_knn_r=RandomizedSearchCV(knn_pipeline,knn_parameter,cv=5,n_iter=5,return_train_score=True)

# %%
classifier_knn_r.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('knn_classifer',
#                                               KNeighborsClassifier())]),
#                    n_iter=5,
#                    param_distributions={'knn_classifer__metric': ['euclidean',
#                                                                   'manhattan'],
#                                         'knn_classifer__n_neighbors': [3, 5, 7,
#                                                                        9, 11],
#                                         'knn_classifer__weights': ['uniform',
#                                                                    'distance']},
#                    return_train_score=True)

# %%
results_knn_r=pd.DataFrame(classifier_knn_r.cv_results_)
results_knn_r
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004346      0.000338         0.003809        0.000531
# 1       0.003855      0.000195         0.003640        0.000520
# 2       0.005604      0.001429         0.004503        0.001021
# 3       0.004493      0.000136         0.003231        0.000054
# 4       0.004847      0.000662         0.003455        0.000359
#
#   param_knn_classifer__weights  param_knn_classifer__n_neighbors  \
# 0                      uniform                                 3
# 1                      uniform                                 5
# 2                     distance                                11
# 3                     distance                                 5
# 4                     distance                                 3
#
#   param_knn_classifer__metric  \
# 0                   manhattan
# 1                   euclidean
# 2                   euclidean
# 3                   euclidean
# 4                   euclidean
#
#                                               params  split0_test_score  \
# 0  {'knn_classifer__weights': 'uniform', 'knn_cla...           0.966667
# 1  {'knn_classifer__weights': 'uniform', 'knn_cla...           0.966667
# 2  {'knn_classifer__weights': 'distance', 'knn_cl...           0.966667
# 3  {'knn_classifer__weights': 'distance', 'knn_cl...           0.966667
# 4  {'knn_classifer__weights': 'distance', 'knn_cl...           0.966667
#
#    split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0           0.966667  ...         0.953333        0.033993                4
# 1           0.966667  ...         0.960000        0.024944                1
# 2           0.966667  ...         0.960000        0.024944                1
# 3           0.966667  ...         0.960000        0.024944                1
# 4           0.966667  ...         0.953333        0.033993                4
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.958333            0.958333            0.966667
# 1            0.958333            0.958333            0.958333
# 2            1.000000            1.000000            1.000000
# 3            1.000000            1.000000            1.000000
# 4            1.000000            1.000000            1.000000
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.966667            0.950000              0.96         0.006236
# 1            0.966667            0.958333              0.96         0.003333
# 2            1.000000            1.000000              1.00         0.000000
# 3            1.000000            1.000000              1.00         0.000000
# 4            1.000000            1.000000              1.00         0.000000
#
# [5 rows x 23 columns]

# %%
print("Best accuracy",classifier.best_score_)
print("Best param",classifier.best_params_)
# Out:
# Best accuracy 0.9666666666666666
# Best param {'knn_classifer__metric': 'euclidean', 'knn_classifer__n_neighbors': 7, 'knn_classifer__weights': 'distance'}
